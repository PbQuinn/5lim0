# %%
from lark import Lark, Transformer

grammar = r"""
  string: ESCAPED_STRING
  # %import common.ESCAPED_STRING
"""
parser = Lark(grammar, start='string')

parser.parse('"Hello world"')

def parse(text):
    print(parser.parse(text).pretty())

parse('"Hello world"')
# Out:
# Tree(Token('RULE', 'string'), [Token('ESCAPED_STRING', '"Hello world"')])
# 0

# %%
grammar = r"""
   num: SIGNED_NUM
   SIGNED_NUM: /
    [+-]?(0|[1-9][0-9]*[.]?[0-9]*)  # the digits
   /x  
   # %ignore " "
"""

parser = Lark(grammar, start='num')
parse('42')
# Out:
# num	42

# %%
grammar = r"""
   num: start
   start: expr|signed_num
   signed_num: /[+-]?(0|[1-9][0-9]*[.]?[0-9]*)/
   expr: add|sub|mul
   add: (add|sub|mul "*")? signed_num
   sub: (sub|mul "*")? signed_num
   mul: (mul "*")? signed_num
   # %ignore " "
"""

parser = Lark(grammar, start='num')
parse('1+2+1')
# Out:
# num
#   start
#     expr
#       add
#         add
#           add
#             signed_num	1
#           signed_num	+2
#         signed_num	+1
